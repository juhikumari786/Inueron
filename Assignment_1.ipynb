# %% [markdown]
# # Assignment_1

# %% [markdown]
# ### 1. What are the differences between operators and values in the following?
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [markdown]
# * -> Multiplication operator
# 'hello' -> String type value
# -87.8 -> Floating type value
# - -> Subtraction operator
# / -> Division operator
# + -> Addition operator
# 6 -> Integer type value

# %% [markdown]
# ### 2. What is the difference between string and variable?
# spam
# 'spam'

# %% [markdown]
# spam -> Here spam is variable
# 'spam' -> Here spam is string

# %% [markdown]
# ### 3. Describe three different data forms.

# %% [markdown]
# Text Type:	str
# Numeric Types:	int, float, complex
# Sequence Types:	list, tuple, range

# %% [markdown]
# ### 4. What makes up an expression? What are the functions of all expressions?

# %% [markdown]
# An expression is a combination of values, variables, operators, and calls to functions. Expressions need to be evaluated.

# %% [markdown]
# ### 5. In this chapter, assignment statements such as spam = 10 were added. What's the difference between a declaration and an expression?

# %% [markdown]
# Declaration -> var spam
# Expression -> spam = 10*.5

# %% [markdown]
# ### 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# 22

# %% [markdown]
# ### 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
# 'spam' * 3

# %% [markdown]
# 'spamspamspam'
# 'spamspamspam'

# %% [markdown]
# ### 8. Why is it that eggs is a true variable name but 100 is not?

# %% [markdown]
# 100 is not true variable name because 100 is numeric value and variable name cannot start with numeric value.

# %% [markdown]
# ### 9. Which of the following three functions may be used to convert a value to an integer, a floating-point number, or a string?

# %% [markdown]
# int(x),long(x),str(x)

# %% [markdown]
# ### 10. What is the error caused by this expression? What would you do about it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# concatenation can only be done between strings, in this expression concatenation is done string and integer
