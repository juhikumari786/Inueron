# %% [markdown]
# # Python_Assignment_4

# %% [markdown]
# ### 1.	Write a Python Program to Find the Factorial of a Number?

# %%
def factorial(n):
    if n==0:
        return 1
    return n*factorial(n-1)

n=6
print("Number is :",n," factorial is ",factorial(n))
# Out:
# Number is : 6  factorial is  720

# %% [markdown]
# ### 2.	Write a Python Program to Display the multiplication Table?

# %%
num=3
for i in range(1,11):
    f=num*i
    print(num," * ",i," = ",f)
# Out:
# 3  *  1  =  3
# 3  *  2  =  6
# 3  *  3  =  9
# 3  *  4  =  12
# 3  *  5  =  15
# 3  *  6  =  18
# 3  *  7  =  21
# 3  *  8  =  24
# 3  *  9  =  27
# 3  *  10  =  30

# %% [markdown]
# ### 3.	Write a Python Program to Print the Fibonacci sequence?

# %%
def fib(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return fib(n-1)+fib(n-2)
    
n=7
for i in range(7):
    print(fib(i))
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8

# %% [markdown]
# ### 4.	Write a Python Program to Check Armstrong Number?

# %%
su=0
n=153
temp=n
while n>0:
    r=n%10;    
    su=su+(r*r*r);    
    n=n//10; 
if temp == su:
    print("Armstrong number")
else:
    print("Not an Armstorng")
# Out:
# Armstrong number

# %% [markdown]
# ### 5.	Write a Python Program to Find Armstrong Number in an Interval?

# %%
num=100
for i in range(150,200):
    su=0
    temp=i
    while i>0:
        r=i%10;    
        su=su+(r*r*r);    
        i=i//10; 
    if temp == su:
        print("Armstrong number")
    else:
        print("Not an Armstorng")
# Out:
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Armstrong number
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng
# Not an Armstorng

# %% [markdown]
# ### 6.	Write a Python Program to Find the Sum of Natural Numbers?

# %%
num=16
su=0
if num<0:
    print("Enter positive no")
else:
    while num>0:
        su+=num
        num-=1
    
print(su)
# Out:
# 136
