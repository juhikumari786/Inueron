# %% [markdown]
# # Assignment_9

# %% [markdown]
# ### 1. To what does a relative path refer?

# %% [markdown]
# Relative paths are relative to the current working directory

# %% [markdown]
# ### 2. What is the first step on an absolute path?

# %% [markdown]
# Absolute paths start with the root folder, such as / or C:\.

# %% [markdown]
# ### 3. On Windows, what does Path('C:/Users') / 'Al' evaluate to?

# %% [markdown]
# On Windows, it evaluates to WindowsPath('C:/Users/Al'). On other operating systems, it evaluates to a different kind of Path object but with the
# same path.

# %% [markdown]
# ### 4. On Windows, what does 'C:/Users' / 'Al' evaluate to?

# %% [markdown]
# The expression 'C:/Users' / 'Al' results in an error, since you can’t use
# the / operator to join two strings.

# %% [markdown]
# ### 5. What do the functions os.getcwd() and os.chdir() do?

# %% [markdown]
# The os.getcwd() function returns the current working directory. The
# os.chdir() function changes the current working directory.

# %% [markdown]
# ### 6. What is the difference between the. and.. folders?

# %% [markdown]
# The . folder is the current folder, and .. is the parent folder

# %% [markdown]
# ### 7. Which part of C:baconeggsspam.txt is the dir name and which part is the base name?

# %% [markdown]
# C:\bacon\eggs is the dir name, while spam.txt is the base name.

# %% [markdown]
# ### 8. What are the three “mode” arguments that the open() function accepts?

# %% [markdown]
# The string 'r' for read mode, 'w' for write mode, and 'a' for
# append mode

# %% [markdown]
# ### 9. What happens if you open existing file in write mode?

# %% [markdown]
# An existing file opened in write mode is erased and completely
# overwritten.

# %% [markdown]
# ### 10. How do you tell the difference between read() and readlines()?

# %% [markdown]
# The read() method returns the file’s entire contents as a single string
# value. The readlines() method returns a list of strings, where each
# string is a line from the file’s contents.

# %% [markdown]
# ### 11. How does a shelf value resemble a data structure?

# %% [markdown]
# A shelf value resembles a dictionary value; it has keys and values, along
# with keys() and values() methods that work similarly to the dictionary
# methods of the same names.
